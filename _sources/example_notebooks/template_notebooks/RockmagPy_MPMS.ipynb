# %%
import pmagpy.ipmag as ipmag

# %%
ipmag.download_magic('./example_data/MPMS/NED18-2c.TXT',print_progress=False)
# Out:
# 1  records written to file  /Users/unimos/0000_Github/PmagPy-docs/example_notebooks/template_notebooks/specimens.txt
# 1  records written to file  /Users/unimos/0000_Github/PmagPy-docs/example_notebooks/template_notebooks/samples.txt
# 1  records written to file  /Users/unimos/0000_Github/PmagPy-docs/example_notebooks/template_notebooks/sites.txt
# 2  records written to file  /Users/unimos/0000_Github/PmagPy-docs/example_notebooks/template_notebooks/locations.txt
# 5  records written to file  /Users/unimos/0000_Github/PmagPy-docs/example_notebooks/template_notebooks/measurements.txt
# 811  records written to file  /Users/unimos/0000_Github/PmagPy-docs/example_notebooks/template_notebooks/measurements_1.txt
# 109  records written to file  /Users/unimos/0000_Github/PmagPy-docs/example_notebooks/template_notebooks/measurements_2.txt
# WARNING:  problem in file with line:
# meas_temp	meas_field_dc	magn_mass	magn_r2_det	timestamp
# skipping....
# WARNING:  problem in file with line:
# ...
